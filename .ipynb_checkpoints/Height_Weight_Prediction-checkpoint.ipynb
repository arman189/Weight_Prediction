# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'height_weight.ui'
#
# Created by: PyQt5 UI code generator 5.15.4
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


from PyQt5 import QtCore, QtGui, QtWidgets
import height_weight_rc


class Ui_HeightWeight(object):
    def setupUi(self, HeightWeight):
        HeightWeight.setObjectName("HeightWeight")
        HeightWeight.resize(840, 679)
        self.label = QtWidgets.QLabel(HeightWeight)
        self.label.setGeometry(QtCore.QRect(0, -220, 841, 911))
        self.label.setText("")
        self.label.setPixmap(QtGui.QPixmap(":/newPrefix/Height_weight.jpg"))
        self.label.setScaledContents(True)
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(HeightWeight)
        self.label_2.setGeometry(QtCore.QRect(250, 120, 121, 71))
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(HeightWeight)
        self.label_3.setGeometry(QtCore.QRect(250, 220, 121, 71))
        self.label_3.setObjectName("label_3")
        self.height = QtWidgets.QLineEdit(HeightWeight)
        self.height.setGeometry(QtCore.QRect(420, 130, 251, 51))
        self.height.setStyleSheet("font: 75 italic 16pt \"Comic Sans MS\";color:rgb(0, 0, 0)")
        self.height.setObjectName("height")
        self.gender = QtWidgets.QLineEdit(HeightWeight)
        self.gender.setGeometry(QtCore.QRect(420, 240, 251, 51))
        self.gender.setStyleSheet("font: 75 italic 16pt \"Comic Sans MS\";color:rgb(0, 0, 0)")
        self.gender.setObjectName("gender")
        self.label_4 = QtWidgets.QLabel(HeightWeight)
        self.label_4.setGeometry(QtCore.QRect(330, 20, 271, 41))
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(HeightWeight)
        self.label_5.setGeometry(QtCore.QRect(620, 500, 151, 71))
        self.label_5.setObjectName("label_5")
        self.predict = QtWidgets.QPushButton(HeightWeight)
        self.predict.setGeometry(QtCore.QRect(480, 360, 131, 61))
        self.predict.setStyleSheet("font: 75 16pt \"Comic Sans MS\";color:rgb(255, 85, 0)")
        self.predict.setObjectName("predict")
        self.weight = QtWidgets.QLineEdit(HeightWeight)
        self.weight.setGeometry(QtCore.QRect(300, 510, 261, 51))
        self.weight.setStyleSheet("font: 75 italic 16pt \"Comic Sans MS\";color:rgb(0, 0, 255)")
        self.weight.setObjectName("weight")

        self.retranslateUi(HeightWeight)
        QtCore.QMetaObject.connectSlotsByName(HeightWeight)

    def retranslateUi(self, HeightWeight):
        _translate = QtCore.QCoreApplication.translate
        HeightWeight.setWindowTitle(_translate("HeightWeight", "Height-Weight Prediction"))
        self.label_2.setText(_translate("HeightWeight", "<html><head/><body><p><span style=\" font-size:18pt; font-weight:600; color:#ffff00;\">Height</span></p></body></html>"))
        self.label_3.setText(_translate("HeightWeight", "<html><head/><body><p><span style=\" font-size:18pt; font-weight:600; color:#ffff00;\">Gender</span></p></body></html>"))
        self.height.setText(_translate("HeightWeight", "hsdkjhkjs"))
        self.gender.setText(_translate("HeightWeight", "skjskfjkl"))
        self.label_4.setText(_translate("HeightWeight", "<html><head/><body><p align=\"center\"><span style=\" font-size:16pt; font-weight:600; text-decoration: underline; color:#00ff00;\">Weight Prediction</span></p></body></html>"))
        self.label_5.setText(_translate("HeightWeight", "<html><head/><body><p><span style=\" font-size:18pt; font-weight:600; color:#ff0000;\">Weight</span></p></body></html>"))
        self.predict.setText(_translate("HeightWeight", "Predict"))
        self.weight.setText(_translate("HeightWeight", "ksjlkfsj"))


    def weight_prediction(self):
        import numpy as np
        import pandas as pd
        import matplotlib.pyplot as plt
        import sklearn
        from sklearn import linear_model #for linear regression

        path="C:\\Users\\ARMAN KHAN\\OneDrive\\Desktop\\Machine Learning\\Project\\Final Project\\Weight-Height\\weight-height"

        data=pd.read_csv(path)
        print(data)

        x=data.drop('Weight',axis='columns')
        print(x)

        y=data.drop(['Gender','Height'],axis='columns')
        print(y)

        plt.scatter(x,y)

        model=linear_model.LinearRegression() #initialize the model
        model.fit(x,y) #train the model

        value=model.predict([[2600]])
        print(value)

        value=model.predict([[5000]])
        print(value)

        # eq. of straight line: y=mx+c
        print(model.coef_) # m

        print(model.intercept_) #c

        y=model.coef_*5000+model.intercept_
        print(y)



if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    HeightWeight = QtWidgets.QWidget()
    ui = Ui_HeightWeight()
    ui.setupUi(HeightWeight)
    HeightWeight.show()
    sys.exit(app.exec_())
